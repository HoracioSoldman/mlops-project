# %% [markdown]
# ### Experimentation for Flight Delay Prediction

# %%
import pandas as pd
from datetime import datetime
import mlflow

# %%
# initialize mlflow params

# above all, we need to run mlflow server by executing:
#  mlflow server --backend-store-uri sqlite:///backend.db --default-artifact-root=artifacts
MLFLOW_TRACKING_URI = "http://127.0.0.1:5000"
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("flight-delay-experiment")
# Out:
# <Experiment: artifact_location='artifacts/1', experiment_id='1', lifecycle_stage='active', name='flight-delay-experiment', tags={}>

# %% [markdown]
# The dataset source: https://www.kaggle.com/datasets/yuanyuwendymu/airline-delay-and-cancellation-data-2009-2018?resource=download&select=2018.csv

# %%
target = ['DEP_DELAY']
data_path = '../data/2018.csv'

# %%
def read_df(file_path, dataset_size_in_million):
    df_chuncks = pd.read_csv(file_path, chunksize=1000000)
    df = pd.DataFrame({"columns":[]})
    index = 0
    for ck in df_chuncks:
        if index < dataset_size_in_million:
            df = pd.concat([df, ck], axis=0, ignore_index=True)
        index+=1
    return df

# %%
def extract_dep_hour(dep_time):
    dep_time = str(int(dep_time))
    
    if len(dep_time) == 3:
        dep_time = f'0{dep_time}'
    return dep_time

# %%
def preprocessing(df_source):
    df= df_source[['FL_DATE', 'OP_CARRIER', 'ORIGIN', 'DEST', 'DEP_TIME', 'DISTANCE', 'CRS_DEP_TIME', 'DEP_DELAY']]
    df['FL_DATE'] = pd.to_datetime(df['FL_DATE'])
    df['FL_DAY'] = df['FL_DATE'].dt.day_name()
    df['DEP_HOUR_MIN'] = df['CRS_DEP_TIME'].apply(lambda x: extract_dep_hour(x))
    df['DEP_HOUR'] = df['DEP_HOUR_MIN'].apply(lambda x: x[:2])
    df['DEP_MIN'] = df['DEP_HOUR_MIN'].apply(lambda x: x[2:])
    df['DEP_DELAY'] = df['DEP_DELAY'].apply(lambda x: abs(x))
    df= df[['FL_DAY','OP_CARRIER', 'ORIGIN', 'DEST', 'DISTANCE', 'DEP_HOUR', 'DEP_MIN', 'DEP_DELAY']]
    
    categorical = ['FL_DAY','OP_CARRIER', 'ORIGIN', 'DEST', 'DEP_HOUR', 'DEP_MIN']
    numerical = ['DISTANCE']
    df[categorical] = df[categorical].astype(str)
    
    train_df = df.drop(columns = target).copy()
    
    return train_df

# %%
df = read_df(data_path, 2)
train_df = preprocessing(df)
# Out:
# /tmp/ipykernel_62774/2146973931.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FL_DATE'] = pd.to_datetime(df['FL_DATE'])
# /tmp/ipykernel_62774/2146973931.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FL_DAY'] = df['FL_DATE'].dt.day_name()
# /tmp/ipykernel_62774/2146973931.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DEP_HOUR_MIN'] = df['CRS_DEP_TIME'].apply(lambda x: extract_dep_hour(x))
# /tmp/ipykernel_62774/2146973931.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DEP_HOUR'] = df['DEP_HOUR_MIN'].apply(lambda x: x[:2])
# /tmp/ipykernel_62774/2146973931.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DEP_MIN'] = df['DEP_HOUR_MIN'].apply(lambda x: x[2:])
# /tmp/ipykernel_62774/2146973931.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DEP_DELAY'] = df['DEP_DELAY'].apply(lambda x: abs(x))

# %%
from sklearn.feature_extraction import DictVectorizer
dv = DictVectorizer()

train_dict = train_df.to_dict(orient='records')
X = dv.fit_transform(train_dict)
y = df[target]

# missing values -> 0
y.fillna(0, inplace=True)
# Out:
# /tmp/ipykernel_62774/662195677.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y.fillna(0, inplace=True)

# %%
# train test validation split
from sklearn.model_selection import train_test_split
# we are going to split our dataset into 80:10:10 as training:test:validation respectively
train_size=0.8
# split the data in training and other dataset
X_train, X_oth, y_train, y_oth = train_test_split(X, y, train_size=0.8)

# for the other data which is the remaining one, we split it into test and validation
test_size = 0.5
X_valid, X_test, y_valid, y_test = train_test_split(X_oth, y_oth, test_size=0.5)

print('X_train: ', X_train.shape) 
print('y_train: ', y_train.shape)
print('X_valid: ', X_valid.shape) 
print('y_valid: ', y_valid.shape)
print('X_test: ', X_test.shape)
print('y_test: ', y_test.shape)
# Out:
# X_train:  (1600000, 831)
# y_train:  (1600000, 1)
# X_valid:  (200000, 831)
# y_valid:  (200000, 1)
# X_test:  (200000, 831)
# y_test:  (200000, 1)

# %%
# the models
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.svm import LinearSVR

from sklearn.metrics import mean_squared_error

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

import xgboost as xgb
import pickle

# %%
# train xgboost model
def best_model_search(train, valid, y_val):
    def objective(params):
        with mlflow.start_run():
            mlflow.set_tag("model", "xgboost")
            mlflow.log_params(params)
            booster = xgb.train(
                params=params,
                dtrain=train,
                num_boost_round=800,
                evals=[(valid, 'validation')],
                early_stopping_rounds=30
            )
            y_pred = booster.predict(valid)
            rmse = mean_squared_error(y_val, y_pred, squared=False)
            mlflow.log_metric("rmse", rmse)

        return {'loss': rmse, 'status': STATUS_OK}

    search_space = {
        'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
        'learning_rate': hp.loguniform('learning_rate', -3, 0),
        'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
        'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
        'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
        'objective': 'reg:linear',
        'seed': 42
    }

    best_result = fmin(
        fn=objective,
        space=search_space,
        algo=tpe.suggest,
        max_evals=1,
        trials=Trials()
    )
    return

# %%
mlflow.sklearn.autolog()
model_files = ['lin_reg.bin', 'lasso.bin', 'lvr.bin', 'xgb.bin']

for index, model_class in enumerate([LinearRegression, Lasso, LinearSVR, xgb]):

    if model_files[index] == 'xgb.bin':
        train = xgb.DMatrix(X_train, label=y_train.values)
        valid = xgb.DMatrix(X_valid, label=y_valid.values)
        best_model_search(train, valid, y_valid.values)
        

    else:
        with mlflow.start_run():

            mlflow.set_tag("model", model_files[index])
            mlflow.log_param("data-path", data_path)

            mlmodel = model_class()
            mlmodel.fit(X_train, y_train.values.ravel())


            with open(f'models/{model_files[index]}', 'wb') as f_out:
                pickle.dump((dv, mlmodel), f_out)

            y_pred = mlmodel.predict(X_valid)
            rmse = mean_squared_error(y_valid, y_pred, squared=False)
            mlflow.log_metric("rmse", rmse)
            mlflow.log_artifact(local_path=f"models/{model_files[index]}", artifact_path="models_pickle")
# Out:
# /home/hrc/.local/share/virtualenvs/mlops-project-i48dIIMg/lib/python3.10/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [07:41:47] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:42.90899
# [1]	validation-rmse:42.81423
# [2]	validation-rmse:42.72980
# [3]	validation-rmse:42.65444
# [4]	validation-rmse:42.58740
# [5]	validation-rmse:42.52740
# [6]	validation-rmse:42.47375
# [7]	validation-rmse:42.42597
# [8]	validation-rmse:42.38199
# [9]	validation-rmse:42.34311
# [10]	validation-rmse:42.30740
# [11]	validation-rmse:42.27594
# [12]	validation-rmse:42.24700
# [13]	validation-rmse:42.22162
# [14]	validation-rmse:42.19819
# [15]	validation-rmse:42.17767
# [16]	validation-rmse:42.15869
# [17]	validation-rmse:42.14110
# [18]	validation-rmse:42.12413
# [19]	validation-rmse:42.10963
# [20]	validation-rmse:42.09646
# [21]	validation-rmse:42.08387
# [22]	validation-rmse:42.07226
# [23]	validation-rmse:42.06165
# [24]	validation-rmse:42.05222
# [25]	validation-rmse:42.04360
# [26]	validation-rmse:42.03470
# [27]	validation-rmse:42.02737
# [28]	validation-rmse:42.02093
# [29]	validation-rmse:42.01539
# [30]	validation-rmse:42.00880
# [31]	validation-rmse:42.00327
# [32]	validation-rmse:41.99770
# [33]	validation-rmse:41.99237
# [34]	validation-rmse:41.98773
# [35]	validation-rmse:41.98257
# [36]	validation-rmse:41.97835
# [37]	validation-rmse:41.97448
# [38]	validation-rmse:41.97099
# [39]	validation-rmse:41.96747
# [40]	validation-rmse:41.96439
# [41]	validation-rmse:41.96073
# [42]	validation-rmse:41.95788
# [43]	validation-rmse:41.95472
# [44]	validation-rmse:41.95132
# [45]	validation-rmse:41.94840
# [46]	validation-rmse:41.94594
# [47]	validation-rmse:41.94344
# [48]	validation-rmse:41.94093
# [49]	validation-rmse:41.93894
# [50]	validation-rmse:41.93627
# [51]	validation-rmse:41.93458
# [52]	validation-rmse:41.93221
# [53]	validation-rmse:41.92994
# [54]	validation-rmse:41.92762
# [55]	validation-rmse:41.92535
# [56]	validation-rmse:41.92394
# [57]	validation-rmse:41.92226
# [58]	validation-rmse:41.92041
# [59]	validation-rmse:41.91911
# [60]	validation-rmse:41.91735
# [61]	validation-rmse:41.91487
# [62]	validation-rmse:41.91442
# [63]	validation-rmse:41.91258
# [64]	validation-rmse:41.91011
# [65]	validation-rmse:41.90872
# [66]	validation-rmse:41.90722
# [67]	validation-rmse:41.90555
# [68]	validation-rmse:41.90410
# [69]	validation-rmse:41.90375
# [70]	validation-rmse:41.90124
# [71]	validation-rmse:41.89982
# [72]	validation-rmse:41.89837
# [73]	validation-rmse:41.89688
# [74]	validation-rmse:41.89648
# [75]	validation-rmse:41.89440
# [76]	validation-rmse:41.89312
# [77]	validation-rmse:41.89152
# [78]	validation-rmse:41.89002
# [79]	validation-rmse:41.88808
# [80]	validation-rmse:41.88633
# [81]	validation-rmse:41.88494
# [82]	validation-rmse:41.88327
# [83]	validation-rmse:41.88209
# [84]	validation-rmse:41.88081
# [85]	validation-rmse:41.88062
# [86]	validation-rmse:41.87914
# [87]	validation-rmse:41.87790
# [88]	validation-rmse:41.87727
# [89]	validation-rmse:41.87622
# [90]	validation-rmse:41.87499
# [91]	validation-rmse:41.87485
# [92]	validation-rmse:41.87309
# [93]	validation-rmse:41.87216
# [94]	validation-rmse:41.87089
# [95]	validation-rmse:41.86862
# [96]	validation-rmse:41.86745
# [97]	validation-rmse:41.86628
# [98]	validation-rmse:41.86520
# [99]	validation-rmse:41.86496
# [100]	validation-rmse:41.86372
# [101]	validation-rmse:41.86238
# [102]	validation-rmse:41.86167
# [103]	validation-rmse:41.86028
# [104]	validation-rmse:41.85899
# [105]	validation-rmse:41.85794
# [106]	validation-rmse:41.85682
# [107]	validation-rmse:41.85642
# [108]	validation-rmse:41.85527
# [109]	validation-rmse:41.85554
# [110]	validation-rmse:41.85477
# [111]	validation-rmse:41.85401
# [112]	validation-rmse:41.85314
# [113]	validation-rmse:41.85190
# [114]	validation-rmse:41.85066
# [115]	validation-rmse:41.84983
# [116]	validation-rmse:41.84913
# [117]	validation-rmse:41.84841
# [118]	validation-rmse:41.84757
# [119]	validation-rmse:41.84663
# [120]	validation-rmse:41.84580
# [121]	validation-rmse:41.84597
# [122]	validation-rmse:41.84495
# [123]	validation-rmse:41.84411
# [124]	validation-rmse:41.84315
# [125]	validation-rmse:41.84272
# [126]	validation-rmse:41.84226
# [127]	validation-rmse:41.84196
# [128]	validation-rmse:41.84073
# [129]	validation-rmse:41.83978
# [130]	validation-rmse:41.83897
# [131]	validation-rmse:41.83835
# [132]	validation-rmse:41.83749
# [133]	validation-rmse:41.83689
# [134]	validation-rmse:41.83602
# [135]	validation-rmse:41.83569
# [136]	validation-rmse:41.83519
# [137]	validation-rmse:41.83457
# [138]	validation-rmse:41.83383
# [139]	validation-rmse:41.83315
# [140]	validation-rmse:41.83206
# [141]	validation-rmse:41.83135
# [142]	validation-rmse:41.83028
# [143]	validation-rmse:41.82979
# [144]	validation-rmse:41.82921
# [145]	validation-rmse:41.82848
# [146]	validation-rmse:41.82777
# [147]	validation-rmse:41.82754
# [148]	validation-rmse:41.82742
# [149]	validation-rmse:41.82730
# [150]	validation-rmse:41.82664
# [151]	validation-rmse:41.82606
# [152]	validation-rmse:41.82563
# [153]	validation-rmse:41.82511
# [154]	validation-rmse:41.82444
# [155]	validation-rmse:41.82374
# [156]	validation-rmse:41.82412
# [157]	validation-rmse:41.82314
# [158]	validation-rmse:41.82262
# [159]	validation-rmse:41.82313
# [160]	validation-rmse:41.82244
# [161]	validation-rmse:41.82168
# [162]	validation-rmse:41.82144
# [163]	validation-rmse:41.82098
# [164]	validation-rmse:41.82060
# [165]	validation-rmse:41.82020
# [166]	validation-rmse:41.81973
# [167]	validation-rmse:41.81906
# [168]	validation-rmse:41.81840
# [169]	validation-rmse:41.81810
# [170]	validation-rmse:41.81773
# [171]	validation-rmse:41.81727
# [172]	validation-rmse:41.81670
# [173]	validation-rmse:41.81646
# [174]	validation-rmse:41.81604
# [175]	validation-rmse:41.81678
# [176]	validation-rmse:41.81650
# [177]	validation-rmse:41.81589
# [178]	validation-rmse:41.81528
# [179]	validation-rmse:41.81519
# [180]	validation-rmse:41.81483
# [181]	validation-rmse:41.81424
# [182]	validation-rmse:41.81395
# [183]	validation-rmse:41.81378
# [184]	validation-rmse:41.81332
# [185]	validation-rmse:41.81279
# [186]	validation-rmse:41.81257
# [187]	validation-rmse:41.81232
# [188]	validation-rmse:41.81194
# [189]	validation-rmse:41.81155
# [190]	validation-rmse:41.81138
# [191]	validation-rmse:41.81128
# [192]	validation-rmse:41.81058
# [193]	validation-rmse:41.81041
# [194]	validation-rmse:41.81005
# [195]	validation-rmse:41.80974
# [196]	validation-rmse:41.80963
# [197]	validation-rmse:41.80927
# [198]	validation-rmse:41.80896
# [199]	validation-rmse:41.80867
# [200]	validation-rmse:41.80818
# [201]	validation-rmse:41.80772
# [202]	validation-rmse:41.80742
# [203]	validation-rmse:41.80703
# [204]	validation-rmse:41.80663
# [205]	validation-rmse:41.80636
# [206]	validation-rmse:41.80601
# [207]	validation-rmse:41.80569
# [208]	validation-rmse:41.80496
# [209]	validation-rmse:41.80468
# [210]	validation-rmse:41.80535
# [211]	validation-rmse:41.80510
# [212]	validation-rmse:41.80512
# [213]	validation-rmse:41.80483
# [214]	validation-rmse:41.80444
# [215]	validation-rmse:41.80411
# [216]	validation-rmse:41.80357
# [217]	validation-rmse:41.80448
# ...
# [344]	validation-rmse:41.79027
# [345]	validation-rmse:41.79011
# [346]	validation-rmse:41.78987
# [347]	validation-rmse:41.78984
# [348]	validation-rmse:41.78974
# [349]	validation-rmse:41.78975
# [350]	validation-rmse:41.78970
# [351]	validation-rmse:41.78945
# [352]	validation-rmse:41.78957
# [353]	validation-rmse:41.78944
# [354]	validation-rmse:41.78937
# [355]	validation-rmse:41.78940
# [356]	validation-rmse:41.78937
# [357]	validation-rmse:41.78919
# [358]	validation-rmse:41.78928
# [359]	validation-rmse:41.78929
# [360]	validation-rmse:41.78958
# [361]	validation-rmse:41.78935
# [362]	validation-rmse:41.78932
# [363]	validation-rmse:41.78926
# [364]	validation-rmse:41.78901
# [365]	validation-rmse:41.78888
# [366]	validation-rmse:41.78898
# [367]	validation-rmse:41.78904
# [368]	validation-rmse:41.78897
# [369]	validation-rmse:41.78885
# [370]	validation-rmse:41.78890
# [371]	validation-rmse:41.78886
# [372]	validation-rmse:41.78866
# [373]	validation-rmse:41.78858
# [374]	validation-rmse:41.78878
# [375]	validation-rmse:41.78863
# [376]	validation-rmse:41.78840
# [377]	validation-rmse:41.78816
# [378]	validation-rmse:41.78811
# [379]	validation-rmse:41.78776
# [380]	validation-rmse:41.78768
# [381]	validation-rmse:41.78788
# [382]	validation-rmse:41.78784
# [383]	validation-rmse:41.78755
# [384]	validation-rmse:41.78744
# [385]	validation-rmse:41.78738
# [386]	validation-rmse:41.78803
# [387]	validation-rmse:41.78921
# [388]	validation-rmse:41.78925
# [389]	validation-rmse:41.78922
# [390]	validation-rmse:41.78939
# [391]	validation-rmse:41.78922
# [392]	validation-rmse:41.78912
# [393]	validation-rmse:41.78912
# [394]	validation-rmse:41.78927
# [395]	validation-rmse:41.78924
# [396]	validation-rmse:41.78905
# [397]	validation-rmse:41.78801
# [398]	validation-rmse:41.78784
# [399]	validation-rmse:41.78791
# [400]	validation-rmse:41.78795
# [401]	validation-rmse:41.78798
# [402]	validation-rmse:41.78784
# [403]	validation-rmse:41.78789
# [404]	validation-rmse:41.78836
# [405]	validation-rmse:41.78831
# [406]	validation-rmse:41.78814
# [407]	validation-rmse:41.78816
# [408]	validation-rmse:41.78810
# [409]	validation-rmse:41.78827
# [410]	validation-rmse:41.78816
# [411]	validation-rmse:41.78821
# [412]	validation-rmse:41.78830
# [413]	validation-rmse:41.78831
# [414]	validation-rmse:41.78860
# [415]	validation-rmse:41.78867
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [03:56<00:00, 236.76s/trial, best loss: 41.7886741167314]
